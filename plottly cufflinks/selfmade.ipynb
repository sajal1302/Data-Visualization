# %%
import pandas as pd
import numpy as np
from plotly import __version__
# %matplotlib inline
import cufflinks as cf

# %%
print(__version__)
# Out:
# 3.7.1

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
#this will connect java script through your notebook.plotly essentially just connect pandas and pytgon to it interactive
#java script library

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#this will allow cs cufflink offline 
cf.go_offline()
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  0.101008  0.022737  1.830768 -0.004783
# 1  0.923263  1.386008  0.194616 -1.220892
# 2 -0.611834 -2.114567 -0.916561  1.077958
# 3 -1.106869  0.724904  0.200380 -0.682471
# 4  0.222745  0.055648  0.217449  1.136503

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div id="866a56b9-453d-4906-8f12-d23dfc747327" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("866a56b9-453d-4906-8f12-d23dfc747327")) {
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=5)
# Out:
# <div id="9789b16f-4d4f-4025-883b-0d65786e76fc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("9789b16f-4d4f-4025-883b-0d65786e76fc")) {
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div id="6c52ec61-9304-4847-81f6-6f94889cf595" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6c52ec61-9304-4847-81f6-6f94889cf595")) {
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div id="8ea6cad6-5ec6-49e0-95be-df357a5f64d8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8ea6cad6-5ec6-49e0-95be-df357a5f64d8")) {
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div id="721c279d-7dd7-45d1-8190-132cb388ae3c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("721c279d-7dd7-45d1-8190-132cb388ae3c")) {
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div id="3deade7a-a082-4ea5-849f-dc2fa1d707fe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("3deade7a-a082-4ea5-849f-dc2fa1d707fe")) {
# ...

# %%
#BOXPLOT
df.iplot(kind='box')
# Out:
# <div id="6be8b5d6-0d1d-4962-877a-c9bc05240d72" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6be8b5d6-0d1d-4962-877a-c9bc05240d72")) {
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div id="cc87ec6a-34ec-4c14-aeee-28c097813678" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("cc87ec6a-34ec-4c14-aeee-28c097813678")) {
# ...

# %%
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div id="561fc1f4-8b13-49f7-bf67-eb0fdd60cbfd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("561fc1f4-8b13-49f7-bf67-eb0fdd60cbfd")) {
# ...

# %%
df.iplot(kind='hist',bins=50)
# Out:
# <div id="284d9728-ae46-4932-8e03-f90ae55eb4d9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("284d9728-ae46-4932-8e03-f90ae55eb4d9")) {
# ...

# %%
#SPREAD :- SPREAD TYPE VISUALIZATION IS USED AS A LOT FOR STOCK DATA
df[['A','B']].iplot(kind='spread')
# Out:
# <div id="18b4dd96-b903-41bf-936a-0bbeb0c7fe6c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("18b4dd96-b903-41bf-936a-0bbeb0c7fe6c")) {
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div id="c4039a0c-d291-44f7-94be-c4ce520438aa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("c4039a0c-d291-44f7-94be-c4ce520438aa")) {
# ...

# %%
df.scatter_matrix()
# Out:
# <div id="33d38a6c-ad69-4822-b12a-955cac6c123d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("33d38a6c-ad69-4822-b12a-955cac6c123d")) {
# ...
